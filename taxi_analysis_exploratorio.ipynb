# %% [markdown]
# # 🚖 Análisis Exploratorio de Datos de Taxis en Nueva York
#
# Este análisis explora los datos de viajes en taxi de la ciudad de Nueva York.
# Se estudiarán las tendencias en los viajes, la duración, la velocidad promedio,
# los patrones de tarifas y otros factores clave.
#
# ### 📌 Contenido:
# 1. **Carga de Datos**
# 2. **Resumen y Limpieza de Datos**
# 3. **Análisis de Variables Clave**
# 4. **Visualización de Patrones**
# 5. **Conclusiones**
#
# Los datos utilizados en este análisis provienen de registros de taxis de 2015 y 2016.

# %% [markdown]
# ## 1️⃣ Carga de Datos

# %%
# Importación de librerías necesarias
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Configuración de estilo para gráficos
plt.style.use('ggplot')

# %%
# Cargar los datos desde el archivo procesado
df = pd.read_csv('/mnt/data/final_taxi_data_filtered.csv')

# Mostrar las primeras filas para revisar la estructura del dataset
df.head()

# %%
df_2015.rename(columns={'RateCodeID': 'RatecodeID'}, inplace=True)

# %%
df_2015['tpep_pickup_datetime'] = pd.to_datetime(df_2015['tpep_pickup_datetime'])
df_2015['tpep_dropoff_datetime'] = pd.to_datetime(df_2015['tpep_dropoff_datetime'])
df_2016['tpep_pickup_datetime'] = pd.to_datetime(df_2016['tpep_pickup_datetime'])
df_2016['tpep_dropoff_datetime'] = pd.to_datetime(df_2016['tpep_dropoff_datetime'])

# %%
df_final = pd.concat([df_2015, df_2016], ignore_index=True)

# %%
df_final['trip_duration'] = (df_final['tpep_dropoff_datetime'] - df_final['tpep_pickup_datetime']).dt.total_seconds() / 60
df_final['speed_mph'] = (df_final['trip_distance'] / df_final['trip_duration']) * 60
df_final['is_weekend'] = df_final['tpep_pickup_datetime'].dt.weekday.isin([5, 6]).astype(int)
df_final['rush_hour'] = df_final['tpep_pickup_datetime'].dt.hour.isin([7, 8, 9, 16, 17, 18]).astype(int)
df_final['fare_per_mile'] = df_final['fare_amount'] / df_final['trip_distance']

# %%
df_final["speed_mph"] = df_final["speed_mph"].fillna(df_final["speed_mph"].median())
df_final["fare_per_mile"] = df_final["fare_per_mile"].fillna(df_final["fare_per_mile"].median())

# %%
numeric_cols = df_final.select_dtypes(include=['float', 'int']).columns
df_final[numeric_cols] = df_final[numeric_cols].round(2)

# %%
df_final["pickup_date"] = df_final["tpep_pickup_datetime"].dt.date
df_final.head()
# Out:
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0         2  2015-01-15 19:05:39   2015-01-15 19:23:42                1
# 1         1  2015-01-10 20:33:38   2015-01-10 20:53:28                1
# 2         1  2015-01-10 20:33:38   2015-01-10 20:43:41                1
# 3         1  2015-01-10 20:33:39   2015-01-10 20:35:31                1
# 4         1  2015-01-10 20:33:39   2015-01-10 20:52:58                1
#
#    trip_distance  pickup_longitude  pickup_latitude  RatecodeID  \
# 0           1.59            -73.99            40.75           1
# 1           3.30            -74.00            40.72           1
# 2           1.80            -73.96            40.80           1
# 3           0.50            -74.01            40.71           1
# 4           3.00            -73.97            40.76           1
#
#   store_and_fwd_flag  dropoff_longitude  ...  tip_amount  tolls_amount  \
# 0                  N             -73.97  ...        3.25           0.0
# ...

# %%
df_final.to_csv('final_taxi_data.csv', index=False)

# %% [markdown]
# ## 2️⃣ Resumen y Limpieza de Datos

# %%
# Información general del dataset
df.info()

# %%
# Estadísticas descriptivas de las variables numéricas
df.describe()

# %% [markdown]
# ## 3️⃣ Análisis de Variables Clave

# %%
# Distribución de la duración de los viajes
import matplotlib.pyplot as plt

plt.figure(figsize=(10,5))
plt.hist(df["trip_duration"], bins=50, edgecolor='black', alpha=0.7)
plt.xlabel("Duración del Viaje (minutos)")
plt.ylabel("Cantidad de Viajes")
plt.title("Distribución de la Duración de los Viajes en Taxi")
plt.show()

# %%
# Relación entre distancia y tarifa
plt.figure(figsize=(8,6))
plt.scatter(df["trip_distance"], df["fare_amount"], alpha=0.5)
plt.xlabel("Distancia del Viaje (millas)")
plt.ylabel("Tarifa ($)")
plt.title("Relación entre Distancia y Tarifa de Viaje")
plt.show()

# %% [markdown]
# ## 4️⃣ Visualización de Patrones

# %%
# Análisis de viajes durante el fin de semana
import seaborn as sns

plt.figure(figsize=(7,5))
sns.boxplot(x=df["is_weekend"], y=df["fare_amount"])
plt.xlabel("¿Fin de Semana? (0=No, 1=Sí)")
plt.ylabel("Tarifa ($)")
plt.title("Distribución de Tarifas entre Días de Semana y Fines de Semana")
plt.show()

# %%
# Distribución de la velocidad promedio de los taxis
plt.figure(figsize=(10,5))
plt.hist(df["speed_mph"], bins=40, edgecolor='black', alpha=0.7)
plt.xlabel("Velocidad Promedio (mph)")
plt.ylabel("Cantidad de Viajes")
plt.title("Distribución de la Velocidad Promedio de los Taxis")
plt.show()

# %% [markdown]
# ## 5️⃣ Conclusiones
#
# - La mayoría de los viajes en taxi duran menos de **30 minutos** y cubren distancias cortas.
# - Existe una relación clara entre la distancia recorrida y la tarifa, aunque hay algunas tarifas anómalas.
# - Los fines de semana parecen tener tarifas más dispersas en comparación con los días de semana.
# - La mayoría de los taxis viajan a velocidades moderadas, pero hay algunos viajes extremadamente rápidos o lentos.
#
# Este análisis nos ayuda a entender mejor los patrones de movilidad en la ciudad de Nueva York.
